# %% [markdown]
# <a href="https://colab.research.google.com/github/romulo-souza/TCCrepo/blob/main/Scripts_Python/Fluidez_Interface/analiseFluidezInterface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#ler csv de cada framework
df_RN = pd.read_csv('jankyFramesRN.csv')
df_Flutter = pd.read_csv('jankyFramesFlutter.csv')

# %%
df_RN
# Out:
#    experimento  janky_frames
# 0            1             5
# 1            2            11
# 2            3             3

# %%
df_Flutter

# %%
media_RN = df_RN['janky_frames'].mean().round(2)
media_RN
# Out:
# np.float64(6.33)

# %%
media_Flutter = df_Flutter['janky_frames'].mean().round(2)
media_Flutter
